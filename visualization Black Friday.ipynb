# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(font_scale=1.8)

# %%
bf=pd.read_csv('C:/Users/Administrator/Desktop/Visualization/BlackFriday/BlackFriday.csv')
bf
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %%
bf['User_ID'].value_counts()
# Out:
# 1001680    1025
# 1004277     978
# 1001941     898
# 1001181     861
# 1000889     822
# 1003618     766
# 1001150     752
# 1001015     739
# 1002909     717
# 1001449     714
# 1002063     708
# 1004344     705
# 1003391     697
# 1003841     697
# 1000424     694
# 1004510     690
# 1001980     684
# 1005795     680
# 1001088     679
# 1004227     676
# 1003808     670
# 1005831     667
# 1004508     651
# 1000549     631
# 1003224     622
# 1003539     616
# 1001285     605
# 1004543     587
# 1003824     583
# 1001010     575
#            ...
# 1004176       8
# 1005117       8
# 1004992       8
# 1004464       8
# 1001318       8
# 1002037       8
# 1002488       8
# 1002965       8
# 1004192       8
# 1005804       8
# 1004527       8
# 1000320       8
# 1003739       8
# 1005043       8
# 1003883       8
# 1000947       8
# 1005174       8
# 1000094       7
# 1002690       7
# 1003275       7
# 1005904       7
# 1003291       7
# 1003542       7
# 1002135       7
# ...

# %%
#Checking null values in dataset
import seaborn as sns
import matplotlib.pyplot as plt
#sns.heatmap(bf.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
#plt.show()

# %%
#Filling na values 

for i in bf:
    if i == 'Product_Category_2':
        bf[i].fillna(0, inplace = True)
for i in bf:
    if i == 'Product_Category_3':
        bf[i].fillna(0, inplace = True)

# %%
#checking isnull
sns.heatmap(bf.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
plt.show()

# %%
sns.heatmap(
    bf.corr(),
    annot=True
)

# %%
fig = plt.figure(figsize=(15,12))
plt.subplot(2,1,1)
plt.title("Purchase Count (Gender Wise)")
sns.countplot(bf.Gender, order = bf['Gender'].value_counts().index)

plt.subplot(2,1,2)
sns.countplot(bf.Age, order = bf['Age'].value_counts().index)
plt.title("Purchase Count (Age Wise)")

plt.tight_layout()
plt.show()

# %%
fig,axes = plt.subplots(nrows=3,ncols=1, figsize=(15,15))
plt.title('Family size histogram by survival')
plt.xlabel('Family Size')
plt.ylabel('# of Passengers')
plt.legend()
sns.barplot(x = 'City_Category', y='Purchase', data=bf, ax= axes[0])
sns.barplot(x = 'Stay_In_Current_City_Years', y='Purchase', data=bf, ax= axes[1])
sns.barplot(x = 'Marital_Status', y='Purchase', data=bf, ax= axes[2])

plt.show()
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
fig,axes = plt.subplots(nrows=3,ncols=1, figsize=(15,10))
sns.barplot(x = 'Gender', y='Purchase', data=bf, ax= axes[0])
sns.barplot(x = 'Age', y='Purchase', data=bf, ax= axes[1])
sns.barplot(x = 'Occupation', y='Purchase', data=bf, ax= axes[2])

plt.show()

# %%
fig,axes = plt.subplots(nrows=1,ncols=1, figsize=(15,10))
sns.boxplot(x='Gender', y = 'Purchase', hue='Age', data = bf)
plt.show()

# %%
fig,axes = plt.subplots(nrows=1,ncols=1, figsize=(15,10))
sns.boxplot(x='Occupation', y = 'Purchase',data = bf)
plt.show()

# %%
fig,axes = plt.subplots(nrows=1,ncols=1, figsize=(15,10))
sns.boxplot(x='City_Category', y = 'Purchase',data = bf)
plt.show()

# %%
fig,axes = plt.subplots(nrows=1,ncols=1, figsize=(15,10))
sns.boxplot(x='Stay_In_Current_City_Years', y = 'Purchase',data = bf)
plt.show()

# %%
fig,axes = plt.subplots(nrows=1,ncols=1, figsize=(15,10))
sns.boxplot(x='Marital_Status', y = 'Purchase',data = bf)
plt.show()

# %% [markdown]
# 1 .Occupation- From above figures, we can infer that those professionals with avg experience of 17 years spends most on the purchases than others
#
# Age We can say that age group of 51-55 spends most followed by 55 + age group
# User Ids Top 5 users who purchased includes - [1004277,1001680,1002909,1001941,1000424]
# Product Ids Top 5 products getting purchased includes - [P00025442,P00110742,P00255842,P00184942,P00059442]
# City_Category Top purchase is made from City_Category - C
# Stay_In_Current_City_Years- Those with 2 years in current city spends most compared to others
# Marital_Status Those who are marred spends more than unmarried ones
# Gender Males purchase more than womens

# %%
sns.jointplot(x='Occupation',y='Purchase',
              data=bf, kind='hex'
             )
# Out:
# C:\Users\hahahaha\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\hahahaha\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#Ananlysis of Purchase capacity as a function of Marital Status across city categories does not show a definitive trend.
#It would lead to a lot of assumptions and might lead to wrong conlcusions.
fig = plt.figure(figsize=(15,8))
sns.violinplot(x='City_Category',y='Purchase',hue='Marital_Status',
               data=bf)

# %% [markdown]
# Picking one key highlight from the below visualisation:
#
# The stark difference in the purchase acoss City_Categories for the Age Group of 55 and above. It is highest in City_Category_B, as compared to the other age groups which tend to show high purchase in City_Category_C.

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,figsize=(18,14))
ax = sns.pointplot(y='Product_Category_1', x='City_Category',hue='Age',
                 data=bf,
                 ax=axes[0,0]
                )
ax = sns.pointplot(y='Product_Category_2', x='City_Category',hue='Age',
                 data=bf,
                 ax=axes[0,1]
                )
ax = sns.pointplot(y='Product_Category_3', x='City_Category', hue='Age',
                 data=bf,
                 ax=axes[1,0]
                )
ax = sns.pointplot(y='Purchase', x='City_Category', hue='Age',
                 data=bf,
                 ax=axes[1,1]
                )

# %%
fig = plt.figure(figsize=(14,8))
g = sns.FacetGrid(bf,col="City_Category")
g.map(sns.barplot, "Gender", "Purchase")
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\seaborn\axisgrid.py:703: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# Above plots
# Clearly people from City_Category C are showing higher purchase capacity as compared to the other two cities on average.
# For City_categories B and C, Males tend to dominate the purchasing, whereas it is the opposite for City Category_C, where Females tend to puchase more than men. It is a useful insight, and it be useful to oserve which age group of females does higher purchasing.
